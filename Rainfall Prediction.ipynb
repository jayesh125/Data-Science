# %%
# Importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# read the data
data = pd.read_csv('/content/drive/MyDrive/Data Science Tutedude/austin_weather.csv')
data.head()
# Out:
#          Date  TempHighF  TempAvgF  TempLowF DewPointHighF DewPointAvgF  \
# 0  2013-12-21         74        60        45            67           49
# 1  2013-12-22         56        48        39            43           36
# 2  2013-12-23         58        45        32            31           27
# 3  2013-12-24         61        46        31            36           28
# 4  2013-12-25         58        50        41            44           40
#
#   DewPointLowF HumidityHighPercent HumidityAvgPercent HumidityLowPercent  ...  \
# 0           43                  93                 75                 57  ...
# 1           28                  93                 68                 43  ...
# 2           23                  76                 52                 27  ...
# 3           21                  89                 56                 22  ...
# 4           36                  86                 71                 56  ...
#
# ...

# %%
# drop unnecessary columns
data = data.drop(['Events', 'Date', "SeaLevelPressureLowInches"], axis=1)
data.head()
# Out:
#    TempHighF  TempAvgF  TempLowF DewPointHighF DewPointAvgF DewPointLowF  \
# 0         74        60        45            67           49           43
# 1         56        48        39            43           36           28
# 2         58        45        32            31           27           23
# 3         61        46        31            36           28           21
# 4         58        50        41            44           40           36
#
#   HumidityHighPercent HumidityAvgPercent HumidityLowPercent  \
# 0                  93                 75                 57
# 1                  93                 68                 43
# 2                  76                 52                 27
# 3                  89                 56                 22
# 4                  86                 71                 56
#
#   SeaLevelPressureHighInches SeaLevelPressureAvgInches VisibilityHighMiles  \
# 0                      29.86                     29.68                  10
# ...

# %%
data = data.replace('T', 0.0)
data = data.replace('-', 0.0)
data.head()
# Out:
#    TempHighF  TempAvgF  TempLowF DewPointHighF DewPointAvgF DewPointLowF  \
# 0         74        60        45            67           49           43
# 1         56        48        39            43           36           28
# 2         58        45        32            31           27           23
# 3         61        46        31            36           28           21
# 4         58        50        41            44           40           36
#
#   HumidityHighPercent HumidityAvgPercent HumidityLowPercent  \
# 0                  93                 75                 57
# 1                  93                 68                 43
# 2                  76                 52                 27
# 3                  89                 56                 22
# 4                  86                 71                 56
#
#   SeaLevelPressureHighInches SeaLevelPressureAvgInches VisibilityHighMiles  \
# 0                      29.86                     29.68                  10
# ...

# %%
data.to_csv('/content/drive/MyDrive/Data Science Tutedude/austin_weather_clean.csv', index=False)

# %%
# !ls /content/drive/MyDrive/Data\ Science\ Tutedude/
# Out:
# austin_weather_clean.csv  covid19_Confirmed_dataset.csv  worldwide_happiness_report.csv
# austin_weather.csv	  covid19_deaths_dataset.csv

# %%
# importing libraies for analysiing and processing data

import sklearn as sk
from sklearn.linear_model import LinearRegression
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %%
data = pd.read_csv('/content/drive/MyDrive/Data Science Tutedude/austin_weather_clean.csv')
data.head()
# Out:
#    TempHighF  TempAvgF  TempLowF  DewPointHighF  DewPointAvgF  DewPointLowF  \
# 0         74        60        45           67.0          49.0          43.0
# 1         56        48        39           43.0          36.0          28.0
# 2         58        45        32           31.0          27.0          23.0
# 3         61        46        31           36.0          28.0          21.0
# 4         58        50        41           44.0          40.0          36.0
#
#    HumidityHighPercent  HumidityAvgPercent  HumidityLowPercent  \
# 0                 93.0                75.0                57.0
# 1                 93.0                68.0                43.0
# 2                 76.0                52.0                27.0
# 3                 89.0                56.0                22.0
# 4                 86.0                71.0                56.0
#
#    SeaLevelPressureHighInches  SeaLevelPressureAvgInches  VisibilityHighMiles  \
# ...

# %%
x = data.drop(['PrecipitationSumInches'], axis=1)

# %%
y = data['PrecipitationSumInches']

# %%
# Reshaping it into 2d vector
# x = x.values.reshape(-1, 1)
y = y.values.reshape(-1, 1)

# %%
y
# Out:
# array([[0.46],
#        [0.  ],
#        [0.  ],
#        ...,
#        [0.  ],
#        [0.  ],
#        [0.  ]])

# %%
# random days for observation
days_index = 798
days = [i for i in range(y.size)]

# %%
# Initialise the linear regression classifier
regressor = LinearRegression()

# train the classifier
regressor.fit(x, y)
# Out:
# LinearRegression()

# %%
# Plot a graph
print("The precipitation trend graph :")
plt.scatter(days, y, color='red')
plt.scatter(days[days_index], y[days_index], color='green')
plt.title('Precipitation Trend')
plt.xlabel('Days')
plt.ylabel('Precipitation')

plt.show()
x_vis = x.filter(['TempAvgF', 'DewPointAvgF', 'HumidityAvgPercent', 'SeaLevelPressureAvgInches', 'VisibilityAvgMiles', 'WindAvgMPH'])
# plt.plot(days, regressor.predict(x_vis), color='blue')
# plt.plot(days, regressor.predict(x), color='blue')
# Out:
# The precipitation trend graph :

# %%
print("The perception vs attributes trend graph: ")
plt.figure(figsize=(12, 8))
for i in range(x_vis.columns.size):
    plt.subplot(3, 2, i + 1)
    plt.scatter(days, x_vis[x_vis.columns.values[i]], color='g')
    plt.scatter(days[days_index], x_vis.iloc[days_index, i], color='r')
    plt.title(x_vis.columns.values[i])
    plt.xlabel('Days')
    plt.ylabel(x_vis.columns.values[i])

plt.tight_layout()  # Adjust layout to prevent overlapping
plt.show()
# Out:
# The perception vs attributes trend graph:
